# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

series = pd.Series([4.2, 2.3, 5.6, 4.5, 4.8, 3.9, 5.9, 2.4, 5.9, 6, 4, 3.7, 5, 5.2, 4.5, 3.6, 5, 6, 2.8, 3.3, 5.5, 4.2, 4.9, 5.1])
series.describe()
series.median()
# Out:
# 4.65

# %%
seriesNew = pd.Series([4.2, 2.3, 6.0, 4.5, 4.8, 3.9, 6.0, 2.4, 5.9, 6, 4, 3.7, 5, 5.2, 4.5, 3.6, 6, 6, 2.8, 3.3, 5.5, 4.2, 4.9, 5.1])
seriesNew.describe()
seriesNew.median()
# Out:
# 4.65

# %%
series.equals(seriesNew)
# Out:
# False

# %%
series.plot(kind="line")

# %%
seriesNew.plot(kind="line")

# %%
series.plot(kind='box', title='Box Plot')

# %%
 hubble = pd.read_table(r"hubble.txt", sep=" ")
 hubble.columns
# Out:
# Index(['distance', 'recession.velocity'], dtype='object')

# %%
b, a = np.polyfit(hubble["distance"], hubble["recession.velocity"], deg=1)
print(a, b)
# Out:
# -40.78364909586042 454.1584409226285

# %%
hubble.plot(kind="scatter", x="distance", y="recession.velocity")

x = np.linspace(hubble["distance"].min() ,hubble["recession.velocity"].max())

plt.plot(x, a+b*x, c="orange")
plt.xlabel("distance") 
plt.ylabel("recession.velocity")
plt.show()
